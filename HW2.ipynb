# %%
#Дан текст (можно взять любой, необязательно этот):варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг Необходимо выделить все биграммы в этом тексте и сохранить их список в какую-либо переменную.
text= "варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг"
words = text.split()
len(words)

bigrams= []

for i in range(len(words) - 1):
    bigram = "%s %s" % (words[i], words[i+1]) 
    print(bigram)
    bigrams.append(bigram)
    
bigrams
# Out:
# варкалось хливкие
# хливкие шорьки
# шорьки пырялись
# пырялись по
# по наве
# наве и
# и хрюкотали
# хрюкотали зелюки
# зелюки как
# как мюмзики
# мюмзики в
# в мове
# мове о
# о бойся
# бойся бармаглота
# бармаглота сын
# сын он
# он так
# так свирлеп
# свирлеп и
# и дик
# дик а
# а в
# в глyще
# глyще рымит
# рымит исполин
# исполин злопастный
# злопастный брандашмыг
# ['варкалось хливкие',
#  'хливкие шорьки',
#  'шорьки пырялись',
#  'пырялись по',
#  'по наве',
#  'наве и',
#  'и хрюкотали',
#  'хрюкотали зелюки',
#  'зелюки как',
#  'как мюмзики',
#  'мюмзики в',
#  'в мове',
#  'мове о',
#  'о бойся',
#  'бойся бармаглота',
#  'бармаглота сын',
#  'сын он',
#  'он так',
#  'так свирлеп',
#  'свирлеп и',
#  'и дик',
#  'дик а',
#  'а в',
#  'в глyще',
#  'глyще рымит',
#  'рымит исполин',
#  'исполин злопастный',
#  'злопастный брандашмыг']

# %%
#Распечатать текущую директорию и список всех файлов и папок в ней. Посчитать и распечатать количество файлов.
import os
print(os.getcwd())

for roots, dirs, files in os.walk ("/Users/ak/Desktop/python-dh-hw/poems"):
    print(roots)
    print(dirs)
    for name in files:
        fullname = os.path.join(roots, name)
        print (fullname)
        
        
file_count = sum(len(files) for _, _, files in os.walk("/Users/ak/Desktop/python-dh-hw/poems"))
print(file_count)
# Out:
# /Users/ak/Desktop/python-dh-hw
# /Users/ak/Desktop/python-dh-hw/poems
# ['сказки', 'котики']
# /Users/ak/Desktop/python-dh-hw/poems/шредингер.txt
# /Users/ak/Desktop/python-dh-hw/poems/.DS_Store
# /Users/ak/Desktop/python-dh-hw/poems/боль.txt
# /Users/ak/Desktop/python-dh-hw/poems/poem.txt
# /Users/ak/Desktop/python-dh-hw/poems/ворон.txt
# /Users/ak/Desktop/python-dh-hw/poems/кладь.txt
# /Users/ak/Desktop/python-dh-hw/poems/деды.txt
# /Users/ak/Desktop/python-dh-hw/poems/ночь.txt
# /Users/ak/Desktop/python-dh-hw/poems/сказки
# []
# /Users/ak/Desktop/python-dh-hw/poems/сказки/король.txt
# /Users/ak/Desktop/python-dh-hw/poems/сказки/крестная.txt
# /Users/ak/Desktop/python-dh-hw/poems/сказки/гримм.txt
# /Users/ak/Desktop/python-dh-hw/poems/сказки/королевич.txt
# /Users/ak/Desktop/python-dh-hw/poems/сказки/яга.txt
# /Users/ak/Desktop/python-dh-hw/poems/котики
# []
# /Users/ak/Desktop/python-dh-hw/poems/котики/кот.txt
# /Users/ak/Desktop/python-dh-hw/poems/котики/пушок.txt
# /Users/ak/Desktop/python-dh-hw/poems/котики/лео.txt
# 16

# %%
#Пройтись циклом по рабочей директории, читая содержимое каждого файла и записывая его в новый файл poems.txt По завершении цикла должен получиться файл со всеми стихотворениями!
for fullname in files:
    with open(fullname, 'r') as f:
        poem = f.read()

        with open('poems.txt', 'a') as f:
            f.write(poem + '\n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-142-80ea4439e432> in <module>()
#       1 #Пройтись циклом по рабочей директории, читая содержимое каждого файла и записывая его в новый файл poems.txt По завершении цикла должен получиться файл со всеми стихотворениями!
#       2 for fullname in files:
# ----> 3     with open(fullname, 'r') as f:
#       4         poem = f.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'шредингер.txt'

# %%
#Скопировать текст, сохранить его в переменную.
poem = """
Удивительная кошка

Несчастная кошка порезала лапу-
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""
#Узнать длину текста в символах.
len(poem)
# Out:
# 290

# %%
#Очистить текст от пунктуации, используя list compehensions. На выходе должен получиться список слов.
words = []

for word in poem.split():
    words.append(word.strip("!?.,-"))
    
print(words)
# Out:
# ['Удивительная', 'кошка', 'Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
#Объединить слова из получившегося списка в строку через пробел.
words2 = ' '.join(words)
print(words2)
# Out:
# Удивительная кошка Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит

# %%
#С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру. На выходе должен получиться список из всех слов стихотворения, написанных с маленькой буквы (не только те, которые изначально были с маленькой буквы, а все).
print([w for w in words2.split() if w.islower()])
words3 = (words2.lower())
print(words3)
# Out:
# ['кошка', 'кошка', 'порезала', 'лапу', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'шарики', 'надо', 'купить', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'по', 'воздуху', 'плавно', 'летит']
# удивительная кошка несчастная кошка порезала лапу сидит и ни шагу не может ступить скорей чтобы вылечить кошкину лапу воздушные шарики надо купить и сразу столпился народ на дороге шумит и кричит и на кошку глядит а кошка отчасти идет по дороге отчасти по воздуху плавно летит

# %%
#Узнать длину текста в словах.
words_ = words3.split()
print(len(words_))
# Out:
# 46

# %%
#Узнать количество уникальных слов.
uniquewords = list()
for word in words3:
        if word in uniquewords:
            pass
        else:
            uniquewords.append(word)
print(len(uniquewords))
# Out:
# 27

# %%
#Распечатать последние 10 слов.
print(words_[36:])
# Out:
# ['кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
#Соединить полученный в пункте 3 список в строку. Слова в строке должны быть написаны через знак переноса строки.
words4 = '\n'.join(words)
print(words4)
# Out:
# удивительная
# кошка
# несчастная
# кошка
# порезала
# лапу
# сидит
# и
# ни
# шагу
# не
# может
# ступить
# скорей
# чтобы
# вылечить
# кошкину
# лапу
# воздушные
# шарики
# надо
# купить
# и
# сразу
# столпился
# народ
# на
# дороге
# шумит
# и
# кричит
# и
# на
# кошку
# глядит
# а
# кошка
# отчасти
# идет
# по
# дороге
# отчасти
# по
# воздуху
# плавно
# летит

# %%
#Распечатать с 20 по 30 символ этой строки (включительно).
print(words4[19:29])
# Out:
# несчастная

# %%
#Разбить текст на биграммы, записать их в переменную и посчитать частотность каждой биграммы. Биграммы должны быть в виде списка кортежей.
len(words_)

bigrams= []

for i in range(len(words_) - 1):
    bigram = "%s %s" % (words_[i], words_[i+1]) 
    bigrams.append(bigram)
    
b = tuple(bigrams)
print(b)

a = {}
for item in b:
    a[item] = a.get(item,0) + 1
print(a)
# Out:
# ('удивительная кошка', 'кошка несчастная', 'несчастная кошка', 'кошка порезала', 'порезала лапу', 'лапу сидит', 'сидит и', 'и ни', 'ни шагу', 'шагу не', 'не может', 'может ступить', 'ступить скорей', 'скорей чтобы', 'чтобы вылечить', 'вылечить кошкину', 'кошкину лапу', 'лапу воздушные', 'воздушные шарики', 'шарики надо', 'надо купить', 'купить и', 'и сразу', 'сразу столпился', 'столпился народ', 'народ на', 'на дороге', 'дороге шумит', 'шумит и', 'и кричит', 'кричит и', 'и на', 'на кошку', 'кошку глядит', 'глядит а', 'а кошка', 'кошка отчасти', 'отчасти идет', 'идет по', 'по дороге', 'дороге отчасти', 'отчасти по', 'по воздуху', 'воздуху плавно', 'плавно летит')
# {'удивительная кошка': 1, 'кошка несчастная': 1, 'несчастная кошка': 1, 'кошка порезала': 1, 'порезала лапу': 1, 'лапу сидит': 1, 'сидит и': 1, 'и ни': 1, 'ни шагу': 1, 'шагу не': 1, 'не может': 1, 'может ступить': 1, 'ступить скорей': 1, 'скорей чтобы': 1, 'чтобы вылечить': 1, 'вылечить кошкину': 1, 'кошкину лапу': 1, 'лапу воздушные': 1, 'воздушные шарики': 1, 'шарики надо': 1, 'надо купить': 1, 'купить и': 1, 'и сразу': 1, 'сразу столпился': 1, 'столпился народ': 1, 'народ на': 1, 'на дороге': 1, 'дороге шумит': 1, 'шумит и': 1, 'и кричит': 1, 'кричит и': 1, 'и на': 1, 'на кошку': 1, 'кошку глядит': 1, 'глядит а': 1, 'а кошка': 1, 'кошка отчасти': 1, 'отчасти идет': 1, 'идет по': 1, 'по дороге': 1, 'дороге отчасти': 1, 'отчасти по': 1, 'по воздуху': 1, 'воздуху плавно': 1, 'плавно летит': 1}
